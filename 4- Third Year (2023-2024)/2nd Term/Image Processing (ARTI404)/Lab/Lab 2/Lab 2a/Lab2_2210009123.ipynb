# %%
# Task 1: Why are we getting gray-scale image?
# Ans: Because there is only one array in 8 bit, Each pixel has a range of 0 to 255, which represents gray-scale from black to white.

# %%
# Task 2:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')
check = df.to_numpy()
sliced = check[2:3, 2:]
plt.matshow(sliced, cmap='gray')
plt.show()
